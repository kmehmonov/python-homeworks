# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1. Basic ploting
# Task: Plot the function $ f(x) = x^2 - 4x + 4 $ for $ x $ values 
# between -10 and 10. Customize the plot with appropriate labels for the axes and a title.


x = np.linspace(-10, 10, 20)
f = x**2 -4*x + 4
plt.figure(figsize=(5,3))
plt.plot(x, f, color = 'red', linestyle = "--", marker = "o", label = "$f(x) = x^2 - 4x + 4 $")
plt.title("Parabolic graph")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
# 2. Sine and Cosine Plot
# Task: Plot $ \sin(x) $ and $ \cos(x) $ on the same graph for $ x $ values ranging from 0 to $ 2\pi $.
# Use different line styles, markers, and colors to distinguish between the two functions. Add a legend.


x = np.linspace(0, 2*np.pi, 20)
y1 = np.sin(x)
y2 = np.cos(x)
plt.figure(figsize=(5,3))
plt.plot(x, y1, 'r-+', label = r"$\sin(x) $")
plt.plot(x, y2, 'k--*', label = r"$\cos(x) $")
plt.title(r"$\sin(x)$ and $\cos(x)$")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
# 3. Subplots
# Task: Create a 2x2 grid of subplots. In each subplot, plot:
# Top-left: $ f(x) = x^3 $
# Top-right: $ f(x) = \sin(x) $
# Bottom-left: $ f(x) = e^x $
# Bottom-right: $ f(x) = \log(x+1) $ (for $ x \geq 0 $)
# Customize each plot with titles, axis labels, and different colors.

x = np.linspace(-5, 5, 20)


fig = plt.figure()
fig.subplots_adjust(hspace=0.5, wspace=0.5)

y1 = x**3
plt.subplot(2, 2, 1)
plt.title("$x^3$")
plt.plot(x, y1, 'r-', label = "$x^3$")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()

y2 = np.sin(x)
plt.subplot(2, 2, 2)
plt.title(r"$\sin(x)$")
plt.plot(x, y2, 'b-.', label = r"$\sin(x)$")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()

y3 = np.exp(x)
plt.subplot(2, 2, 3)
plt.title(r"$e^x$")
plt.plot(x, y3, 'k:', label = r"$e^x$")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()

x = x[x>0]
y4 = np.log(x + 1)
plt.subplot(2, 2, 4)
plt.title(r"$ f(x) = \log(x+1) $ (for $ x \geq 0 $")
plt.plot(x, y4, 'g--', label = r"$ f(x) = \log(x+1) $ (for $ x \geq 0 $")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
# 4. Scatter Plot
# Task: Create a scatter plot of 100 random points in a 2D space.
# The x and y values should be randomly generated from a uniform distribution
# between 0 and 10. Use different colors and markers for the points. Add a title, axis labels, and a grid.

x = np.random.uniform(0, 10, 100)
y = np.random.uniform(0, 10, 100)
existed_markers = ['o', 's', 'D', '*', '^', 'v', '>', '<', 'P', 'X']
markers = np.random.choice(existed_markers, size=100)
colors = np.random.rand(100, 3)
sizes = np.random.rand(100) * 50 
plt.figure(figsize=(8, 6))
for i in range(len(x)):
    plt.scatter(
        x[i], y[i], 
        color=colors[i], 
        marker=markers[i], 
        s=sizes[i], 
        edgecolor='k', alpha=0.7
    )

plt.title("Scatter Plot with Different Colors and Markers")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(visible=True, which="both", axis="both")
plt.show()

# %%
# 5. Histogram
# Task: Generate a random dataset of 1000 values sampled from a normal distribution (mean=0, std=1). 
# Plot a histogram of the data with 30 bins. Add a title and axis labels. Adjust the transparency of
#  the bars using the alpha parameter.


dataset = np.random.normal(0, 1, 1000)
plt.hist(dataset, 30, alpha = 0.7, edgecolor="k")
plt.title("Normal distribution")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
# 6. 3D Plotting
# Task: Create a 3D surface plot for the function $ f(x, y) = \cos(x^2 + y^2) $ 
# over the range of $ x $ and $ y $ values from -5 to 5. Use a suitable colormap
# and add a colorbar. Set appropriate labels for the axes and title.


x = y = np.linspace(-5, 5, 50)
xx, yy = np.meshgrid(x, y)
zz = np.cos(xx**2 + xx**2)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(projection='3d')
surf = ax.plot_surface(xx, yy, zz)
cbar = fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
cbar.set_label('Function Value')

ax.set_title(r"3D Surface Plot of $f(x, y) = \cos(x^2 + y^2)$")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
plt.show()

# %%
# 7. Bar Chart
# Task: Create a vertical bar chart displaying the sales data for five different products:
#  ['Product A', 'Product B', 'Product C', 'Product D', 'Product E']. 
# The sales values for each product are [200, 150, 250, 175, 225]. 
# Customize the chart with a title, axis labels, and different bar colors.

# %%
products = ["A", "B", "C", "D", "E"]
values = [200, 150, 250, 175, 225]
colors = ["red", "blue", "black", "green", "yellow"]

plt.bar(products, values, color = colors)
plt.title("Sales data")
plt.xlabel("Products")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
# 8. Stacked Bar Chart
# Task: Create a stacked bar chart that shows the contribution of three different categories
#  ('Category A', 'Category B', and 'Category C') over four time periods ('T1', 'T2', 'T3', 'T4'). 
# Use sample data for each category at each time period. Customize the chart with a title, axis labels, and a legend.


categories = ['Category A', 'Category B', 'Category C']
time_periods = ['T1', 'T2', 'T3', 'T4']

data_A = [3, 5, 2, 6]
data_B = [4, 6, 3, 4]
data_C = [2, 4, 5, 3]

x = np.arange(len(time_periods))

plt.bar(x, data_A, label='Category A', color='skyblue')
plt.bar(x, data_B, bottom=data_A, label='Category B', color='lightgreen')
plt.bar(x, data_C, bottom=np.array(data_A) + np.array(data_B), label='Category C', color='salmon')

plt.title("Stacked Bar Chart of Categories Over Time", fontsize=14)
plt.xlabel("Time Periods", fontsize=12)
plt.ylabel("Values", fontsize=12)
plt.xticks(x, time_periods) 
plt.legend(title="Categories")

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
